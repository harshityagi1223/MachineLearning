# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
path='/content/gdrive/MyDrive/CA683- Main Assignment/AmazonFashionUpdated.xlsx'
amazon_fashion = pd.read_excel(path)

# %%
path1='/content/gdrive/MyDrive/CA683- Main Assignment/AmazonBeautyUpdated.xlsx'
amazon_beauty = pd.read_excel(path1)

# %%
frames = [amazon_fashion,amazon_beauty]
result = pd.concat(frames)

# %%
result.to_excel('AmazonReviewIntegrated.xlsx', index=False)

# %%
len(amazon_fashion.index)
# Out:
# 65098

# %%
len(amazon_beauty.index)
# Out:
# 5269

# %%
len(result.index)
# Out:
# 70367

# %%
path2='/content/gdrive/MyDrive/CA683- Main Assignment/AmazonOfficeProductUpdated.xlsx'
amazon_office = pd.read_excel(path2)

# %%
frames.append(amazon_office)

# %%
result = pd.concat(frames)

# %%
len(amazon_office.index)
# Out:
# 65151

# %%
len(result.index)
# Out:
# 135518

# %%
result.to_excel('AmazonReviewIntegrated.xlsx', index=False)
